# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
count
# Out:
# [['UNK', 418391],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430),
#  ('two', 192644),
#  ('is', 183153),
#  ('as', 131815),
#  ('eight', 125285),
#  ('for', 118445),
#  ('s', 116710),
#  ('five', 115789),
#  ('three', 114775),
#  ('was', 112807),
#  ('by', 111831),
#  ('that', 109510),
#  ('four', 108182),
#  ('six', 102145),
#  ('seven', 99683),
#  ('with', 95603),
#  ('on', 91250),
#  ('are', 76527),
#  ('it', 73334),
#  ('from', 72871),
#  ('or', 68945),
#  ('his', 62603),
#  ('an', 61925),
#  ('be', 61281),
#  ('this', 58832),
#  ('which', 54788),
#  ('at', 54576),
#  ('he', 53573),
#  ('also', 44358),
#  ('not', 44033),
#  ('have', 39712),
#  ('were', 39086),
#  ('has', 37866),
#  ('but', 35358),
#  ('other', 32433),
#  ('their', 31523),
#  ('its', 29567),
#  ('first', 28810),
#  ('they', 28553),
#  ('some', 28161),
#  ('had', 28100),
#  ('all', 26229),
#  ('more', 26223),
#  ('most', 25563),
#  ('can', 25519),
#  ('been', 25383),
#  ('such', 24413),
#  ('many', 24096),
#  ('who', 23997),
#  ('new', 23770),
#  ('used', 22737),
#  ('there', 22707),
#  ('after', 21125),
#  ('when', 20623),
#  ('into', 20484),
#  ('american', 20477),
#  ('time', 20412),
#  ('these', 19864),
#  ('only', 19463),
#  ('see', 19206),
#  ('may', 19115),
#  ('than', 18807),
#  ('world', 17949),
#  ('i', 17581),
#  ('b', 17516),
#  ('would', 17377),
#  ('d', 17236),
#  ('no', 16155),
#  ('however', 15861),
#  ('between', 15737),
#  ('about', 15574),
#  ('over', 15122),
#  ('years', 14935),
#  ('states', 14916),
#  ('people', 14696),
#  ('war', 14629),
#  ('during', 14578),
#  ('united', 14494),
#  ('known', 14437),
#  ('if', 14420),
#  ('called', 14151),
#  ('use', 14011),
#  ('th', 13380),
#  ('system', 13296),
#  ('often', 12987),
#  ('state', 12904),
#  ('so', 12722),
#  ('history', 12623),
#  ('will', 12560),
#  ('up', 12445),
#  ('while', 12363),
#  ('where', 12347),
#  ('city', 12275),
#  ('being', 11931),
#  ('english', 11868),
#  ('then', 11847),
#  ('any', 11803),
#  ('both', 11755),
#  ('under', 11753),
#  ('out', 11721),
#  ('made', 11701),
#  ('well', 11537),
#  ('her', 11536),
#  ('e', 11426),
#  ('number', 11399),
#  ('government', 11323),
#  ('them', 11285),
#  ('m', 10976),
#  ('later', 10971),
#  ('since', 10691),
#  ('him', 10629),
#  ('part', 10627),
#  ('name', 10572),
#  ('c', 10561),
#  ('century', 10550),
#  ('through', 10371),
#  ('because', 10332),
#  ('x', 10307),
#  ('university', 10195),
#  ('early', 10172),
#  ('life', 10096),
#  ('british', 10056),
#  ('year', 9858),
#  ('like', 9854),
#  ('same', 9774),
#  ('including', 9633),
#  ('became', 9591),
#  ('example', 9539),
#  ('day', 9534),
#  ('each', 9500),
#  ('even', 9412),
#  ('work', 9388),
#  ('language', 9375),
#  ('although', 9286),
#  ('several', 9168),
#  ('form', 9133),
#  ('john', 8956),
#  ('u', 8928),
#  ('national', 8904),
#  ('very', 8861),
#  ('much', 8822),
#  ('g', 8773),
#  ('french', 8736),
#  ('before', 8700),
#  ('general', 8659),
#  ('what', 8581),
#  ('t', 8491),
#  ('against', 8432),
#  ('n', 8372),
#  ('high', 8337),
#  ('links', 8312),
#  ('could', 8304),
#  ('based', 8244),
#  ('those', 8209),
#  ('now', 8206),
#  ('second', 8110),
#  ('de', 8002),
#  ('music', 7987),
#  ('another', 7933),
#  ('large', 7898),
#  ('she', 7896),
#  ('f', 7878),
#  ('external', 7862),
#  ('german', 7858),
#  ('different', 7797),
#  ('modern', 7790),
#  ('great', 7770),
#  ('do', 7763),
#  ('common', 7698),
#  ('set', 7682),
#  ('list', 7672),
#  ('south', 7628),
#  ('series', 7611),
#  ('major', 7585),
#  ('game', 7553),
#  ('power', 7522),
#  ('long', 7488),
#  ('country', 7481),
#  ('king', 7456),
#  ('law', 7435),
#  ('group', 7417),
#  ('film', 7400),
#  ('still', 7378),
#  ('until', 7368),
#  ('north', 7328),
#  ('international', 7262),
#  ('term', 7219),
#  ('we', 7118),
#  ('end', 7113),
#  ('book', 7110),
#  ('found', 7043),
#  ('own', 7034),
#  ('political', 6970),
#  ('party', 6943),
#  ('order', 6908),
#  ('usually', 6872),
#  ('president', 6865),
#  ('church', 6786),
#  ('you', 6690),
#  ('death', 6684),
#  ('theory', 6604),
#  ('area', 6591),
#  ('around', 6576),
#  ('include', 6531),
#  ('god', 6518),
#  ('ii', 6494),
#  ('way', 6433),
#  ('did', 6419),
#  ('military', 6410),
#  ('population', 6400),
#  ('using', 6384),
#  ('though', 6362),
#  ('small', 6361),
#  ('following', 6300),
#  ('within', 6238),
#  ('non', 6220),
#  ('left', 6184),
#  ('human', 6184),
#  ('main', 6166),
#  ('among', 6146),
#  ('point', 6141),
#  ('r', 6064),
#  ('due', 6056),
#  ('p', 6001),
#  ('considered', 5985),
#  ('public', 5976),
#  ('popular', 5967),
#  ('computer', 5874),
#  ('west', 5862),
#  ('family', 5857),
#  ('east', 5854),
#  ('information', 5844),
#  ('important', 5843),
#  ('european', 5806),
#  ('man', 5778),
#  ('sometimes', 5761),
#  ('right', 5758),
#  ('old', 5711),
#  ('free', 5684),
#  ('word', 5678),
#  ('without', 5661),
#  ('last', 5654),
#  ('us', 5652),
#  ('members', 5634),
#  ('given', 5605),
#  ('times', 5582),
#  ('roman', 5468),
#  ('make', 5450),
#  ('h', 5404),
#  ('age', 5350),
#  ('place', 5345),
#  ('l', 5343),
#  ('thus', 5319),
#  ('science', 5314),
#  ('case', 5289),
#  ('become', 5268),
#  ('systems', 5262),
#  ('union', 5248),
#  ('born', 5246),
#  ('york', 5243),
#  ('line', 5236),
#  ('countries', 5231),
#  ('does', 5221),
#  ('isbn', 5216),
#  ('st', 5207),
#  ('control', 5196),
#  ('various', 5163),
#  ('others', 5160),
#  ('house', 5157),
#  ('article', 5143),
#  ('island', 5124),
#  ('should', 5113),
#  ('led', 5108),
#  ('back', 5105),
#  ('period', 5099),
#  ('player', 5096),
#  ('europe', 5094),
#  ('languages', 5087),
#  ('central', 5070),
#  ('water', 5025),
#  ('few', 5013),
#  ('western', 5010),
#  ('home', 5007),
#  ('began', 5004),
#  ('generally', 4979),
#  ('less', 4974),
#  ('k', 4970),
#  ('similar', 4939),
#  ('written', 4916),
#  ('original', 4910),
#  ('best', 4902),
#  ('must', 4898),
#  ('according', 4884),
#  ('school', 4872),
#  ('france', 4813),
#  ('air', 4802),
#  ('single', 4801),
#  ('force', 4776),
#  ('v', 4762),
#  ('land', 4755),
#  ('groups', 4731),
#  ('down', 4728),
#  ('how', 4727),
#  ('works', 4724),
#  ('development', 4721),
#  ('official', 4720),
#  ('support', 4686),
#  ('england', 4641),
#  ('j', 4612),
#  ('rather', 4605),
#  ('data', 4586),
#  ('space', 4586),
#  ('greek', 4577),
#  ('km', 4574),
#  ('named', 4551),
#  ('germany', 4539),
#  ('just', 4528),
#  ('games', 4527),
#  ('said', 4483),
#  ('version', 4472),
#  ('late', 4471),
#  ('earth', 4457),
#  ('company', 4448),
#  ('every', 4446),
#  ('economic', 4435),
#  ('short', 4433),
#  ('published', 4430),
#  ('black', 4429),
#  ('army', 4418),
#  ('off', 4414),
#  ('london', 4399),
#  ('million', 4386),
#  ('body', 4383),
#  ('field', 4352),
#  ('christian', 4347),
#  ('either', 4330),
#  ('social', 4307),
#  ('empire', 4307),
#  ('o', 4299),
#  ('developed', 4270),
#  ('standard', 4269),
#  ('court', 4268),
#  ('service', 4260),
#  ('kingdom', 4257),
#  ('along', 4241),
#  ('college', 4236),
#  ('republic', 4231),
#  ('sea', 4212),
#  ('america', 4202),
#  ('today', 4198),
#  ('result', 4193),
#  ('held', 4178),
#  ('team', 4176),
#  ('light', 4172),
#  ('means', 4165),
#  ('never', 4127),
#  ('especially', 4125),
#  ('third', 4121),
#  ('further', 4118),
#  ('forces', 4114),
#  ('character', 4114),
#  ('take', 4105),
#  ('men', 4078),
#  ('society', 4067),
#  ('show', 4064),
#  ('open', 4063),
#  ('possible', 4051),
#  ('fact', 4042),
#  ('battle', 4034),
#  ('took', 4013),
#  ('former', 4007),
#  ('books', 3992),
#  ('soviet', 3985),
#  ('river', 3984),
#  ('children', 3978),
#  ('having', 3964),
#  ('good', 3962),
#  ('local', 3960),
#  ('current', 3955),
#  ('son', 3955),
#  ('process', 3949),
#  ('natural', 3947),
#  ('present', 3922),
#  ('himself', 3919),
#  ('islands', 3903),
#  ('total', 3891),
#  ('near', 3874),
#  ('white', 3866),
#  ('days', 3863),
#  ('person', 3855),
#  ('itself', 3843),
#  ('seen', 3831),
#  ('culture', 3809),
#  ('little', 3805),
#  ('above', 3782),
#  ('software', 3773),
#  ('largest', 3772),
#  ('words', 3771),
#  ('upon', 3768),
#  ('level', 3767),
#  ('father', 3762),
#  ('created', 3760),
#  ('side', 3760),
#  ('red', 3755),
#  ('references', 3747),
#  ('press', 3745),
#  ('full', 3734),
#  ('region', 3726),
#  ('almost', 3717),
#  ('al', 3714),
#  ('image', 3714),
#  ('famous', 3708),
#  ('play', 3702),
#  ('came', 3698),
#  ('role', 3691),
#  ('once', 3686),
#  ('certain', 3675),
#  ('league', 3663),
#  ('jewish', 3662),
#  ('james', 3653),
#  ('january', 3650),
#  ('site', 3639),
#  ('again', 3616),
#  ('numbers', 3611),
#  ('art', 3611),
#  ('member', 3601),
#  ('areas', 3599),
#  ('movement', 3595),
#  ('religious', 3588),
#  ('type', 3588),
#  ('march', 3583),
#  ('community', 3581),
#  ('story', 3573),
#  ('played', 3572),
#  ('production', 3570),
#  ('released', 3555),
#  ('center', 3548),
#  ('rights', 3546),
#  ('real', 3545),
#  ('related', 3536),
#  ('foreign', 3528),
#  ('low', 3524),
#  ('ancient', 3523),
#  ('terms', 3519),
#  ('view', 3519),
#  ('source', 3503),
#  ('act', 3502),
#  ('minister', 3493),
#  ('change', 3483),
#  ('energy', 3464),
#  ('produced', 3457),
#  ('research', 3452),
#  ('actor', 3451),
#  ('making', 3448),
#  ('december', 3443),
#  ('civil', 3443),
#  ('women', 3442),
#  ('special', 3441),
#  ('style', 3438),
#  ('japanese', 3437),
#  ('design', 3437),
#  ('william', 3437),
#  ('available', 3435),
#  ('chinese', 3430),
#  ('forms', 3429),
#  ('canada', 3428),
#  ('northern', 3423),
#  ('died', 3418),
#  ('class', 3412),
#  ('living', 3410),
#  ('next', 3406),
#  ('particular', 3404),
#  ('program', 3403),
#  ('council', 3401),
#  ('television', 3395),
#  ('head', 3376),
#  ('david', 3368),
#  ('china', 3365),
#  ('middle', 3363),
#  ('established', 3360),
#  ('hand', 3356),
#  ('bc', 3356),
#  ('far', 3352),
#  ('july', 3333),
#  ('function', 3330),
#  ('position', 3318),
#  ('y', 3311),
#  ('built', 3310),
#  ('george', 3307),
#  ('band', 3304),
#  ('together', 3303),
#  ('w', 3301),
#  ('latin', 3290),
#  ('thought', 3277),
#  ('eastern', 3276),
#  ('charles', 3268),
#  ('parts', 3266),
#  ('instead', 3259),
#  ('study', 3248),
#  ('india', 3242),
#  ('might', 3242),
#  ('code', 3240),
#  ('meaning', 3213),
#  ('included', 3213),
#  ('trade', 3207),
#  ('per', 3206),
#  ('june', 3195),
#  ('least', 3185),
#  ('half', 3176),
#  ('model', 3141),
#  ('economy', 3136),
#  ('prime', 3135),
#  ('traditional', 3133),
#  ('always', 3131),
#  ('capital', 3129),
#  ('range', 3125),
#  ('emperor', 3119),
#  ('november', 3119),
#  ('young', 3109),
#  ('anti', 3103),
#  ('final', 3102),
#  ('text', 3098),
#  ('players', 3088),
#  ('uk', 3079),
#  ('april', 3069),
#  ('run', 3063),
#  ('september', 3055),
#  ('addition', 3050),
#  ('radio', 3050),
#  ('live', 3046),
#  ('august', 3044),
#  ('note', 3043),
#  ('taken', 3043),
#  ('italian', 3037),
#  ('lost', 3035),
#  ('nature', 3027),
#  ('project', 3022),
#  ('technology', 3017),
#  ('spanish', 3011),
#  ('october', 3009),
#  ('rate', 3002),
#  ('recent', 3002),
#  ('won', 2989),
#  ('true', 2965),
#  ('value', 2964),
#  ('uses', 2963),
#  ('russian', 2961),
#  ('est', 2959),
#  ('wrote', 2935),
#  ('effect', 2933),
#  ('album', 2932),
#  ('southern', 2927),
#  ('africa', 2923),
#  ('whose', 2914),
#  ('top', 2913),
#  ('historical', 2899),
#  ('australia', 2895),
#  ('catholic', 2888),
#  ('particularly', 2882),
#  ('self', 2879),
#  ('structure', 2876),
#  ('record', 2863),
#  ('evidence', 2857),
#  ('rule', 2852),
#  ('themselves', 2852),
#  ('influence', 2845),
#  ('cases', 2843),
#  ('subject', 2830),
#  ('referred', 2829),
#  ('continued', 2822),
#  ('nations', 2821),
#  ('rock', 2819),
#  ('below', 2819),
#  ('japan', 2817),
#  ('com', 2810),
#  ('song', 2809),
#  ('throughout', 2806),
#  ('names', 2806),
#  ('female', 2797),
#  ('title', 2796),
#  ('therefore', 2795),
#  ('our', 2795),
#  ('office', 2785),
#  ('star', 2784),
#  ('paul', 2777),
#  ('too', 2775),
#  ('cities', 2773),
#  ('independent', 2771),
#  ('february', 2771),
#  ('author', 2769),
#  ('problem', 2767),
#  ('species', 2761),
#  ('done', 2759),
#  ('education', 2759),
#  ('philosophy', 2758),
#  ('come', 2755),
#  ('higher', 2753),
#  ('originally', 2752),
#  ('market', 2748),
#  ('town', 2746),
#  ('my', 2745),
#  ('season', 2741),
#  ('love', 2740),
#  ('strong', 2736),
#  ('israel', 2735),
#  ('irish', 2731),
#  ('writer', 2731),
#  ('films', 2727),
#  ('elements', 2723),
#  ('robert', 2722),
#  ('whether', 2719),
#  ('despite', 2716),
#  ('eventually', 2714),
#  ('here', 2709),
#  ('football', 2708),
#  ('action', 2699),
#  ('internet', 2697),
#  ('individual', 2693),
#  ('sound', 2693),
#  ('network', 2691),
#  ('described', 2685),
#  ('practice', 2681),
#  ('characters', 2674),
#  ('re', 2664),
#  ('royal', 2663),
#  ('la', 2660),
#  ('events', 2650),
#  ('formed', 2644),
#  ('commonly', 2638),
#  ('base', 2633),
#  ('received', 2632),
#  ('problems', 2628),
#  ('african', 2628),
#  ('food', 2623),
#  ('jews', 2620),
#  ('able', 2619),
#  ('male', 2615),
#  ('typically', 2595),
#  ('mass', 2595),
#  ('complex', 2593),
#  ('lower', 2583),
#  ('includes', 2576),
#  ('outside', 2574),
#  ('legal', 2562),
#  ('complete', 2561),
#  ('parliament', 2554),
#  ('significant', 2554),
#  ('actually', 2553),
#  ('business', 2542),
#  ('fiction', 2540),
#  ('physical', 2539),
#  ('followed', 2537),
#  ('deaths', 2530),
#  ('key', 2527),
#  ('widely', 2525),
#  ('leader', 2525),
#  ('page', 2520),
#  ('basic', 2519),
#  ('types', 2518),
#  ('henry', 2494),
#  ('elected', 2493),
#  ('beginning', 2493),
#  ('fire', 2489),
#  ('building', 2480),
#  ('independence', 2478),
#  ('went', 2475),
#  ('aircraft', 2471),
#  ('movie', 2471),
#  ('ever', 2470),
#  ('canadian', 2468),
#  ('material', 2464),
#  ('births', 2462),
#  ('video', 2461),
#  ('news', 2458),
#  ('future', 2457),
#  ('scientific', 2456),
#  ('simply', 2454),
#  ('go', 2451),
#  ('defined', 2449),
#  ('laws', 2444),
#  ('get', 2440),
#  ('close', 2439),
#  ('industry', 2434),
#  ('specific', 2432),
#  ('examples', 2431),
#  ('services', 2404),
#  ('believe', 2404),
#  ('idea', 2398),
#  ('introduced', 2397),
#  ('method', 2397),
#  ('points', 2396),
#  ('return', 2395),
#  ('cause', 2392),
#  ('indian', 2389),
#  ('britain', 2384),
#  ('features', 2380),
#  ('majority', 2379),
#  ('size', 2379),
#  ('post', 2376),
#  ('lead', 2375),
#  ('organization', 2374),
#  ('cannot', 2373),
#  ('designed', 2364),
#  ('ireland', 2362),
#  ('cross', 2361),
#  ('classical', 2359),
#  ('personal', 2357),
#  ('writing', 2356),
#  ('concept', 2353),
#  ('required', 2349),
#  ('associated', 2349),
#  ('soon', 2343),
#  ('changes', 2337),
#  ('located', 2336),
#  ('california', 2336),
#  ('sense', 2331),
#  ('believed', 2319),
#  ('started', 2313),
#  ('away', 2313),
#  ('co', 2308),
#  ('religion', 2304),
#  ('mother', 2303),
#  ('county', 2300),
#  ('rules', 2299),
#  ('studies', 2298),
#  ('yet', 2296),
#  ('find', 2290),
#  ('knowledge', 2289),
#  ('put', 2288),
#  ('founded', 2282),
#  ('policy', 2278),
#  ('currently', 2275),
#  ('provide', 2272),
#  ('working', 2271),
#  ('media', 2267),
#  ('election', 2266),
#  ('australian', 2260),
#  ('me', 2256),
#  ('thomas', 2255),
#  ('allowed', 2252),
#  ('russia', 2251),
#  ('greater', 2249),
#  ('earlier', 2249),
#  ('limited', 2248),
#  ('object', 2243),
#  ('brought', 2241),
#  ('online', 2236),
#  ('association', 2231),
#  ('lord', 2231),
#  ('mostly', 2227),
#  ('blue', 2223),
#  ('across', 2222),
#  ('constitution', 2222),
#  ('added', 2218),
#  ('interest', 2217),
#  ('things', 2216),
#  ('relations', 2215),
#  ('speed', 2206),
#  ('federal', 2200),
#  ('singer', 2195),
#  ('effects', 2194),
#  ('growth', 2193),
#  ('sources', 2192),
#  ('your', 2189),
#  ('remains', 2183),
#  ('z', 2182),
#  ('gave', 2178),
#  ('probably', 2178),
#  ('simple', 2177),
#  ('attack', 2175),
#  ('longer', 2174),
#  ('reference', 2171),
#  ('saint', 2168),
#  ('success', 2164),
#  ('killed', 2163),
#  ('past', 2162),
#  ('career', 2162),
#  ('need', 2159),
#  ('park', 2156),
#  ('definition', 2147),
#  ('say', 2139),
#  ('etc', 2137),
#  ('give', 2133),
#  ('peace', 2133),
#  ('chief', 2130),
#  ('stories', 2128),
#  ('security', 2126),
#  ('wide', 2125),
#  ('ball', 2124),
#  ('saw', 2119),
#  ('machine', 2117),
#  ('better', 2116),
#  ('cell', 2115),
#  ('leading', 2114),
#  ('becomes', 2111),
#  ('spain', 2109),
#  ('larger', 2109),
#  ('night', 2108),
#  ('products', 2108),
#  ('parties', 2108),
#  ('remained', 2105),
#  ('prize', 2103),
#  ('website', 2102),
#  ('months', 2102),
#  ('big', 2102),
#  ('cultural', 2101),
#  ('money', 2101),
#  ('help', 2099),
#  ('territory', 2099),
#  ('private', 2098),
#  ('moved', 2098),
#  ('wife', 2093),
#  ('letter', 2093),
#  ('politics', 2090),
#  ('lines', 2090),
#  ('largely', 2089),
#  ('contains', 2086),
#  ('companies', 2084),
#  ('lake', 2080),
#  ('perhaps', 2079),
#  ('green', 2074),
#  ('already', 2070),
#  ('iii', 2069),
#  ('dead', 2069),
#  ('library', 2068),
#  ('separate', 2067),
#  ('refer', 2066),
#  ('makes', 2065),
#  ('appeared', 2064),
#  ('dutch', 2060),
#  ('holy', 2059),
#  ('era', 2057),
#  ('novel', 2054),
#  ('successful', 2052),
#  ('italy', 2050),
#  ('letters', 2049),
#  ('results', 2048),
#  ('matter', 2045),
#  ('produce', 2042),
#  ('origin', 2041),
#  ('claim', 2039),
#  ('whole', 2034),
#  ('directly', 2033),
#  ('attempt', 2033),
#  ('actress', 2031),
#  ('surface', 2030),
#  ('revolution', 2029),
#  ('highly', 2026),
#  ('caused', 2025),
#  ('status', 2024),
#  ('musical', 2022),
#  ('richard', 2021),
#  ('commercial', 2020),
#  ('division', 2018),
#  ('color', 2017),
#  ('release', 2013),
#  ('health', 2013),
#  ('coast', 2013),
#  ('latter', 2012),
#  ('authority', 2009),
#  ('treaty', 2007),
#  ('turn', 2005),
#  ('michael', 2000),
#  ('nation', 1995),
#  ('direct', 1994),
#  ('asia', 1992),
#  ('edition', 1990),
#  ('programming', 1989),
#  ('playing', 1981),
#  ('date', 1980),
#  ('whom', 1977),
#  ('mary', 1977),
#  ('native', 1977),
#  ('married', 1973),
#  ('towards', 1971),
#  ('issues', 1967),
#  ('double', 1966),
#  ('primary', 1959),
#  ('basis', 1959),
#  ('enough', 1958),
#  ('allow', 1958),
#  ('memory', 1957),
#  ('reason', 1954),
#  ('web', 1952),
#  ('exist', 1950),
#  ('provided', 1948),
#  ('functions', 1945),
#  ('course', 1945),
#  ('oil', 1945),
#  ('alexander', 1944),
#  ('analysis', 1944),
#  ('chemical', 1944),
#  ('mid', 1941),
#  ('replaced', 1941),
#  ('queen', 1940),
#  ('tv', 1938),
#  ('sun', 1938),
#  ('claims', 1938),
#  ('literature', 1936),
#  ('metal', 1935),
#  ('amount', 1934),
#  ('divided', 1930),
#  ('blood', 1927),
#  ('likely', 1926),
#  ('access', 1924),
#  ('average', 1924),
#  ('length', 1922),
#  ('smaller', 1921),
#  ('medical', 1919),
#  ('property', 1918),
#  ('students', 1916),
#  ('degree', 1915),
#  ('elections', 1914),
#  ('club', 1913),
#  ('claimed', 1912),
#  ('performance', 1911),
#  ('director', 1907),
#  ('digital', 1905),
#  ('front', 1904),
#  ('museum', 1904),
#  ('tradition', 1903),
#  ('difficult', 1903),
#  ('nearly', 1902),
#  ('schools', 1900),
#  ('washington', 1899),
#  ('gas', 1897),
#  ('jesus', 1896),
#  ('map', 1896),
#  ('louis', 1895),
#  ('rome', 1895),
#  ('unit', 1892),
#  ('baseball', 1890),
#  ('mind', 1888),
#  ('mark', 1887),
#  ('peter', 1887),
#  ('collection', 1883),
#  ('product', 1881),
#  ('congress', 1880),
#  ('programs', 1872),
#  ('changed', 1871),
#  ('ideas', 1870),
#  ('moon', 1868),
#  ('entire', 1866),
#  ('user', 1865),
#  ('ground', 1864),
#  ('records', 1862),
#  ('frequently', 1861),
#  ('increase', 1860),
#  ('highest', 1859),
#  ('finally', 1858),
#  ('sent', 1858),
#  ('board', 1857),
#  ('don', 1856),
#  ('notable', 1854),
#  ('read', 1852),
#  ('methods', 1852),
#  ('recently', 1851),
#  ('bit', 1849),
#  ('variety', 1843),
#  ('involved', 1843),
#  ('call', 1842),
#  ('democratic', 1841),
#  ('ten', 1840),
#  ('served', 1836),
#  ('minor', 1830),
#  ('hard', 1828),
#  ('objects', 1823),
#  ('birth', 1823),
#  ('increased', 1819),
#  ('nuclear', 1819),
#  ('section', 1813),
#  ('street', 1812),
#  ('windows', 1811),
#  ('relatively', 1810),
#  ('car', 1809),
#  ('move', 1808),
#  ('create', 1807),
#  ('returned', 1807),
#  ('bank', 1806),
#  ('conditions', 1805),
#  ('operation', 1802),
#  ('relationship', 1801),
#  ('adopted', 1801),
#  ('christ', 1800),
#  ('hall', 1797),
#  ('appear', 1794),
#  ('rest', 1790),
#  ('child', 1789),
#  ('element', 1787),
#  ('appears', 1786),
#  ('takes', 1783),
#  ...]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'term', 'originated', 'as', 'of']

# %%
print(batch)
print(labels)
# Out:
# [12 12 12 12  6  6  6  6]
# [[ 195]
#  [5239]
#  [   6]
#  [3084]
#  [ 195]
#  [3084]
#  [  12]
#  [   2]]

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.659830
# Nearest to up: tir, imap, wy, mishna, selden, pickens, ultrasound, builds,
# Nearest to states: atv, checkpoint, valhalla, tsiolkovsky, vegetal, stepwise, bavarians, sta,
# Nearest to may: sanctioned, berkelium, mccall, dua, stripper, bearded, servicio, ethiopian,
# Nearest to b: drinkers, erupts, tragic, emissary, visionaries, dorians, censoring, sharps,
# Nearest to UNK: sira, semantically, printer, inputs, confounded, fermion, antoninianus, scoping,
# Nearest to people: bocce, unitas, abijah, delineation, topics, planters, funny, symbolize,
# Nearest to between: counterbalanced, cosmos, escorted, scanners, displaced, oilseed, milosevic, rewind,
# Nearest to system: indonesians, handfasting, signifier, riverfront, petomane, attendees, impede, chests,
# Nearest to no: unforeseen, resolved, ips, multihull, note, overcame, stanton, earp,
# Nearest to during: convalescence, erythromycin, bv, reigns, americanized, nested, abortions, miraculously,
# Nearest to more: slit, faithless, completely, cthulhu, bagapsh, wobble, synthesised, yyyy,
# Nearest to will: canyons, canonized, aalto, henotheism, legitimate, susima, pharmacological, sensei,
# Nearest to only: equal, recycling, ligases, scorned, looping, lifecycle, liberian, canteen,
# Nearest to but: retard, declassified, pushkin, carradine, ontology, wreck, stormy, nu,
# Nearest to by: eruption, semiology, clowning, carta, intervarsity, zoran, meditating, jeff,
# Nearest to war: gravity, perpetuating, mips, jazeera, option, bedroom, feathers, breaking,
# Average loss at step 2000: 4.359310
# Average loss at step 4000: 3.862327
# Average loss at step 6000: 3.789903
# Average loss at step 8000: 3.684709
# Average loss at step 10000: 3.615691
# Nearest to up: imap, shawnee, wy, tir, cameroon, llywelyn, ferrite, continuous,
# Nearest to states: valhalla, checkpoint, vegetal, royalists, qxd, bavarians, atv, dependence,
# Nearest to may: would, could, can, noticing, might, upheavals, hawaii, barbados,
# Nearest to b: drinkers, tragic, emissary, preston, conrad, censoring, visionaries, issuing,
# Nearest to UNK: memex, fans, looser, statutory, machiavelli, sprouts, bluebird, arcane,
# Nearest to people: unitas, vdp, yen, years, kipling, wyatt, timbuktu, biog,
# Nearest to between: cosmos, milosevic, escorted, puritans, east, scanners, inauguration, transcending,
# Nearest to system: handfasting, pressuring, positive, chondrites, dietrich, shatter, attendees, signifier,
# Nearest to no: it, also, farmed, sacrilegious, nicolas, they, recent, pannonian,
# Nearest to during: majors, reigns, mozambique, erythromycin, idiot, oran, loyal, guardian,
# Nearest to more: completely, slit, yyyy, swaps, justifying, faithless, most, remembered,
# Nearest to will: borax, sensei, canonized, henotheism, then, imprinted, canyons, snell,
# Nearest to only: unrest, amy, mandibles, toughness, laurier, scorned, capillary, sibylla,
# Nearest to but: convicts, carradine, he, although, jonson, could, infrequent, were,
# Nearest to by: was, shares, germans, at, from, deshima, buyer, intervarsity,
# Nearest to war: option, dba, gravity, jazeera, tinted, mayhem, christmas, peter,
# Average loss at step 12000: 3.606667
# Average loss at step 14000: 3.569276
# Average loss at step 16000: 3.413244
# Average loss at step 18000: 3.458016
# Average loss at step 20000: 3.543052
# Nearest to up: cameroon, shawnee, wy, ferrite, synthesizers, peggy, differential, transmitters,
# Nearest to states: valhalla, dependence, bavarians, cities, checkpoint, interfacing, royalists, tsiolkovsky,
# Nearest to may: can, would, might, could, will, must, should, bilinear,
# Nearest to b: d, tragic, preston, thicker, diagnostics, menacing, drinkers, hey,
# Nearest to UNK: li, fans, uninhabited, smith, i, fis, craters, hari,
# Nearest to people: years, vdp, alp, yen, men, resounding, komm, contiguous,
# Nearest to between: cosmos, with, milosevic, escorted, from, regarding, east, inauguration,
# Nearest to system: handfasting, pressuring, kjv, positive, attendees, impede, dietrich, perish,
# Nearest to no: nicolas, any, sojourn, intrinsic, a, neuro, recent, sacrilegious,
# Nearest to during: by, majors, sparking, at, following, erythromycin, reigns, mozambique,
# Nearest to more: less, most, completely, slit, justifying, swaps, rather, faithless,
# Nearest to will: would, may, can, must, could, to, should, then,
# Nearest to only: livermore, always, unrest, pickles, capillary, toughness, taunus, it,
# Nearest to but: which, however, and, though, although, while, that, is,
# Nearest to by: through, be, during, been, with, for, germans, meditating,
# Nearest to war: jazeera, tinted, gravity, option, zawahiri, huike, clams, draught,
# Average loss at step 22000: 3.506561
# Average loss at step 24000: 3.494627
# Average loss at step 26000: 3.482735
# Average loss at step 28000: 3.478161
# Average loss at step 30000: 3.505661
# Nearest to up: cameroon, shawnee, pym, them, transmitters, peggy, down, synthesizers,
# Nearest to states: cities, valhalla, wine, dependence, royalists, abad, checkpoint, bavarians,
# Nearest to may: can, would, will, might, could, must, should, orson,
# Nearest to b: d, tragic, menacing, microcosm, riso, hey, inquiring, pollute,
# Nearest to UNK: payoff, amongst, humorist, condensate, comb, wisconsin, machiavelli, hilberg,
# Nearest to people: years, alp, vdp, komm, audiogalaxy, yen, individuals, contiguous,
# Nearest to between: cosmos, with, from, milosevic, escorted, east, before, tolson,
# Nearest to system: kjv, handfasting, leaving, merry, systems, attendees, pressuring, fokker,
# Nearest to no: any, nicolas, sojourn, neuro, intrinsic, a, sacrilegious, werke,
# Nearest to during: in, at, after, when, since, mozambique, fastest, under,
# Nearest to more: less, very, most, completely, rather, swaps, justifying, rsted,
# Nearest to will: would, may, can, must, could, should, might, does,
# Nearest to only: consulship, toughness, obtaining, unrest, always, taunus, laurier, pickles,
# Nearest to but: however, although, and, though, while, that, when, which,
# Nearest to by: in, qadhafi, with, deshima, was, wording, compensating, outside,
# Nearest to war: jazeera, gravity, germany, munro, option, christmas, advocated, zawahiri,
# Average loss at step 32000: 3.501248
# Average loss at step 34000: 3.495581
# Average loss at step 36000: 3.454905
# Average loss at step 38000: 3.301507
# Average loss at step 40000: 3.430106
# Nearest to up: cameroon, them, down, back, him, out, shawnee, off,
# Nearest to states: kingdom, cities, valhalla, murky, interfacing, abad, wine, cabbage,
# Nearest to may: can, would, will, might, could, must, should, does,
# Nearest to b: d, UNK, c, k, j, inquiring, archie, p,
# Nearest to UNK: b, agave, twinning, hari, temps, gyeongsang, overflows, physicist,
# Nearest to people: men, komm, years, individuals, someone, vdp, seoul, scholars,
# Nearest to between: tolson, cosmos, escorted, among, before, milosevic, across, with,
# Nearest to system: systems, merry, attendees, fokker, fastened, perish, kjv, freelance,
# Nearest to no: any, nicolas, neuro, sojourn, still, sacrilegious, werke, planned,
# Nearest to during: at, after, fastest, when, throughout, mays, under, since,
# Nearest to more: less, most, very, completely, rsted, longer, rather, ciboney,
# Nearest to will: would, can, may, must, could, should, might, does,
# Nearest to only: necessary, iwama, unrest, eloquence, commonly, place, turbofans, pickles,
# Nearest to but: however, although, while, though, and, cluetrain, it, who,
# Nearest to by: compensating, through, be, wording, deshima, as, carta, penis,
# Nearest to war: jazeera, storyteller, continuing, advocated, huike, constitute, christmas, zawahiri,
# Average loss at step 42000: 3.432336
# Average loss at step 44000: 3.449912
# Average loss at step 46000: 3.450915
# Average loss at step 48000: 3.355544
# Average loss at step 50000: 3.382534
# Nearest to up: out, off, them, down, back, cameroon, him, pym,
# Nearest to states: kingdom, nations, abad, cities, pasted, botha, valhalla, polluting,
# Nearest to may: can, would, will, might, could, should, must, does,
# Nearest to b: d, c, k, p, n, olden, inquiring, x,
# Nearest to UNK: surreal, decaying, looser, aga, fela, li, pence, brown,
# Nearest to people: men, years, scholars, komm, individuals, children, jews, min,
# Nearest to between: with, among, tolson, across, escorted, cosmos, in, before,
# Nearest to system: systems, fokker, merry, freelance, chondrites, impede, propulsion, attendees,
# Nearest to no: any, nicolas, cpa, sojourn, enzymes, serum, loran, recite,
# Nearest to during: after, when, in, at, throughout, sixties, while, fastest,
# Nearest to more: less, most, very, longer, emotions, dipping, ciboney, completely,
# Nearest to will: would, can, could, may, must, should, might, does,
# Nearest to only: always, compensation, unrest, fezzan, eon, placid, glottis, taunus,
# Nearest to but: however, although, while, though, and, when, where, cluetrain,
# Nearest to by: through, deshima, was, being, unbaptized, coral, pendleton, quarters,
# Nearest to war: christmas, jazeera, transhumanism, storyteller, advocated, huike, ruppert, nadia,
# Average loss at step 52000: 3.432494
# Average loss at step 54000: 3.432068
# Average loss at step 56000: 3.435071
# Average loss at step 58000: 3.398159
# Average loss at step 60000: 3.394691
# Nearest to up: off, out, them, down, back, him, cameroon, transmitters,
# Nearest to states: kingdom, nations, cities, pasted, wine, technologies, polluting, temair,
# Nearest to may: can, would, will, might, should, could, must, does,
# Nearest to b: d, c, p, x, n, k, f, olden,
# Nearest to UNK: huldrych, vadim, li, references, com, swede, agape, panoramic,
# Nearest to people: men, scholars, years, individuals, americans, seoul, komm, jews,
# Nearest to between: with, among, tolson, across, escorted, through, cosmos, over,
# Nearest to system: systems, fokker, attendees, carbonates, perish, kjv, chondrites, propulsion,
# Nearest to no: any, enzymes, cpa, sojourn, inflexible, nicolas, lar, recite,
# Nearest to during: after, when, before, in, throughout, while, sixties, following,
# Nearest to more: less, very, most, smaller, completely, rather, causal, increasingly,
# Nearest to will: would, could, must, may, can, should, might, does,
# Nearest to only: always, unrest, eon, glottis, compensation, taunus, still, cathars,
# Nearest to but: however, although, and, though, than, while, really, yet,
# Nearest to by: through, buyer, unbaptized, including, bead, pendleton, compensating, using,
# Nearest to war: during, christmas, ammonia, transhumanism, advocated, zawahiri, spectacularly, jazeera,
# Average loss at step 62000: 3.240780
# Average loss at step 64000: 3.253619
# Average loss at step 66000: 3.403280
# Average loss at step 68000: 3.392384
# Average loss at step 70000: 3.362189
# Nearest to up: off, them, out, down, back, him, transmitters, into,
# Nearest to states: kingdom, nations, polluting, pasted, zak, botha, technologies, wine,
# Nearest to may: can, will, would, might, could, must, should, cannot,
# Nearest to b: d, n, f, x, k, p, c, h,
# Nearest to UNK: fela, manet, excise, uninhabited, masamune, laughton, pediatrics, sdram,
# Nearest to people: men, women, scholars, individuals, americans, children, someone, others,
# Nearest to between: across, among, with, escorted, tolson, through, from, in,
# Nearest to system: systems, fokker, chondrites, outpatient, attendees, carbonates, completely, cartoon,
# Nearest to no: any, cpa, enzymes, little, inflexible, sojourn, nicolas, lar,
# Nearest to during: after, in, before, when, throughout, until, sixties, while,
# Nearest to more: less, most, very, rather, completely, longer, quite, extremely,
# Nearest to will: would, may, could, can, must, should, might, cannot,
# Nearest to only: always, typically, cathars, still, not, play, usually, toughness,
# Nearest to but: however, and, although, than, while, that, really, though,
# Nearest to by: through, using, buyer, in, qadhafi, compensating, deshima, as,
# Nearest to war: haircut, transhumanism, ammonia, coretta, ruppert, transitioning, draught, advocated,
# Average loss at step 72000: 3.370487
# Average loss at step 74000: 3.350397
# Average loss at step 76000: 3.314965
# Average loss at step 78000: 3.347125
# Average loss at step 80000: 3.379229
# Nearest to up: off, out, them, down, back, him, transmitters, synthesizers,
# Nearest to states: kingdom, nations, pasted, polluting, murky, trading, zak, countries,
# Nearest to may: can, will, would, must, might, could, should, cannot,
# Nearest to b: d, c, x, p, n, ruskin, inquiring, microcosm,
# Nearest to UNK: brown, hari, li, ed, fj, xl, sira, transpose,
# Nearest to people: men, women, individuals, scholars, children, americans, someone, others,
# Nearest to between: among, across, escorted, through, from, with, within, tolson,
# Nearest to system: systems, fokker, outpatient, chondrites, merry, attendees, cartoon, khaled,
# Nearest to no: little, loran, serum, any, nicolas, cpa, weighted, inflexible,
# Nearest to during: after, when, in, before, although, throughout, until, while,
# Nearest to more: less, very, most, quite, ciboney, extremely, causal, rather,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to only: always, last, freighter, first, team, trusts, eon, still,
# Nearest to but: however, although, while, and, though, really, see, than,
# Nearest to by: using, through, carta, from, wording, pared, thebaid, unbaptized,
# Nearest to war: ammonia, transhumanism, wars, haircut, severan, spectacularly, tutorial, advocated,
# Average loss at step 82000: 3.406872
# Average loss at step 84000: 3.409311
# Average loss at step 86000: 3.390431
# Average loss at step 88000: 3.350946
# Average loss at step 90000: 3.366040
# Nearest to up: off, out, them, down, back, him, synthesizers, bipolar,
# Nearest to states: nations, kingdom, us, murky, cities, zak, aargau, pasted,
# Nearest to may: can, would, could, must, might, will, should, cannot,
# Nearest to b: d, c, f, inquiring, ruskin, h, emissary, n,
# Nearest to UNK: surreal, bookmakers, looser, li, schoolboy, knossos, payoff, baker,
# Nearest to people: men, children, women, americans, scholars, someone, individuals, scientists,
# Nearest to between: across, among, with, through, escorted, within, tolson, from,
# Nearest to system: systems, fokker, attendees, outpatient, merry, cronquist, carbonates, kjv,
# Nearest to no: little, any, inflexible, enzymes, loran, ethno, cpa, serum,
# Nearest to during: after, before, when, while, although, in, until, throughout,
# Nearest to more: less, very, most, increasingly, quite, rather, extremely, causal,
# Nearest to will: would, could, must, can, may, should, might, cannot,
# Nearest to only: even, always, team, merely, equal, just, still, entourage,
# Nearest to but: however, although, and, while, really, that, yet, though,
# Nearest to by: through, using, pared, without, bribe, with, under, for,
# Nearest to war: wars, arab, germans, haircut, transhumanism, tutorial, during, ammonia,
# Average loss at step 92000: 3.397743
# Average loss at step 94000: 3.258776
# Average loss at step 96000: 3.357683
# Average loss at step 98000: 3.246104
# Average loss at step 100000: 3.357988
# Nearest to up: off, out, down, them, back, him, bipolar, synthesizers,
# Nearest to states: nations, kingdom, us, murky, technologies, zak, cities, pasted,
# Nearest to may: can, could, must, would, might, should, will, cannot,
# Nearest to b: d, french, c, lmi, cmb, wace, microcosm, emissary,
# Nearest to UNK: payoff, prat, hari, window, prinz, couldn, subfamily, skates,
# Nearest to people: men, children, women, scholars, americans, someone, individuals, scientists,
# Nearest to between: among, across, with, escorted, through, tolson, over, within,
# Nearest to system: systems, program, model, fokker, khaled, process, pressuring, attendees,
# Nearest to no: little, any, loran, cpa, ethno, weighted, serum, nicolas,
# Nearest to during: after, in, throughout, when, before, until, despite, at,
# Nearest to more: less, most, very, increasingly, higher, extremely, quite, rather,
# Nearest to will: would, must, can, could, may, should, might, cannot,
# Nearest to only: always, merely, compensation, renderer, still, actually, just, equal,
# Nearest to but: however, although, and, though, while, really, which, actually,
# Nearest to by: through, including, when, qadhafi, with, without, buyer, using,
# Nearest to war: wars, transitioning, arab, transhumanism, ruppert, germans, ammonia, conflict,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
from itertools import compress

def generate_batch_cbow(data, batch_size, num_skips, skip_window):
    '''
    Batch generator for CBOW (Continuous Bag of Words).
    batch should be a shape of (batch_size, num_skips)
    Parameters
    ----------
    data: list of index of words
    batch_size: number of words in each mini-batch
    num_skips: number of surrounding words on both direction (2: one word ahead and one word following)
    skip_window: number of words at both ends of a sentence to skip (1: skip the first and last word of a sentence)
    '''
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span) # used for collecting data[data_index] in the sliding window
    # collect the first window of words
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # move the sliding window  
    for i in range(batch_size):
        mask = [1] * span
        mask[skip_window] = 0 
        batch[i, :] = list(compress(buffer, mask)) # all surrounding words
        labels[i, 0] = buffer[skip_window] # the word at the center 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(data, 8, num_skips, skip_window)
    print(batch)
    print(labels)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[x] for x in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li[0]] for li in labels])
    print('\n\n')
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# [[5239   12]
#  [3084    6]
#  [  12  195]
#  [   6    2]
#  [ 195 3137]
#  [   2   46]
#  [3137   59]
#  [  46  156]]
# [[3084]
#  [  12]
#  [   6]
#  [ 195]
#  [   2]
#  [3137]
#  [  46]
#  [  59]]
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
#
#
# [[5239 3084    6  195]
#  [3084   12  195    2]
#  [  12    6    2 3137]
#  [   6  195 3137   46]
#  [ 195    2   46   59]
#  [   2 3137   59  156]
#  [3137   46  156  128]
#  [  46   59  128  742]]
# [[  12]
#  [   6]
#  [ 195]
#  [   2]
#  [3137]
#  [  46]
#  [  59]
#  [ 156]]
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      data, batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.286948
# Nearest to had: corps, ottoman, suitcase, coulomb, speght, tournaments, wumpus, wark,
# Nearest to for: disparate, pairs, idiot, stifle, coordinating, rear, postulate, anthropologists,
# Nearest to would: front, stemmed, bara, julmust, chanson, palaestina, adiabatic, purification,
# Nearest to two: surroundings, watermelon, garc, conscripted, cosgrave, freiherr, uighur, cares,
# Nearest to new: gum, downing, dosage, goldstein, dunkirk, pins, sebald, attend,
# Nearest to a: regularity, downing, proper, plundering, relaxed, ethnic, bauer, cosmic,
# Nearest to at: wuhan, middlesbrough, oceanography, nevertheless, broadside, shifted, catered, pass,
# Nearest to d: donovan, col, bahnhof, brunner, loot, antonym, symphonic, plot,
# Nearest to of: hidalgo, satchmo, vines, ducati, hermione, multitasking, checkpoint, eminem,
# Nearest to people: perfecting, pacified, mauryan, gaddis, tactically, mallory, welcomed, hyperion,
# Nearest to th: telephone, oscillator, sprout, witted, padded, biosphere, deliberations, strut,
# Nearest to only: minyan, tarleton, singapore, labor, bullet, leuven, consortium, ibizan,
# Nearest to into: rigoletto, pillaged, syllabus, musket, emotional, piaget, chagrin, freak,
# Nearest to more: confess, jul, southeast, loops, balances, lazenby, beau, maduro,
# Nearest to been: floorball, considers, parodying, gini, fukuda, centronics, accumulates, that,
# Nearest to by: contestants, megara, identifiers, derives, pemberton, nazarene, tendons, dreamcast,
# Average loss at step 2000: 4.132833
# Average loss at step 4000: 3.578195
# Average loss at step 6000: 3.400467
# Average loss at step 8000: 3.242913
# Average loss at step 10000: 3.174235
# Nearest to had: has, have, was, were, having, became, sternberg, naturalisation,
# Nearest to for: berry, idiot, before, andree, wittgenstein, during, elmendorf, by,
# Nearest to would: could, can, will, may, might, must, should, pani,
# Nearest to two: four, six, three, nine, five, eight, seven, zero,
# Nearest to new: gum, floor, excited, downing, manganese, consecrations, attend, orie,
# Nearest to a: the, vince, gaia, sasaki, this, telepathic, aleuts, sinclair,
# Nearest to at: in, after, nevertheless, ucl, assess, nther, gunman, rims,
# Nearest to d: b, watkins, donovan, raid, afi, gut, wen, drummer,
# Nearest to of: same, subnational, hidalgo, in, glorantha, linton, cfcs, fibrous,
# Nearest to people: perfecting, extensible, tactically, elliott, repealing, insulted, ytv, abolitionist,
# Nearest to th: monosyllabic, sprout, hosni, lair, rd, ff, wrangling, shriver,
# Nearest to only: minyan, singapore, hamdi, baka, brenner, ratifying, hacked, barrel,
# Nearest to into: cellar, from, conway, albigensians, pillaged, former, syllabus, eithne,
# Nearest to more: less, increasingly, most, very, typologically, uh, registrar, dreidel,
# Nearest to been: raisin, be, become, asymptotes, floorball, parodying, draftsman, absorptive,
# Nearest to by: hurley, estas, erase, for, rematch, conveyor, mcclelland, megara,
# Average loss at step 12000: 3.198832
# Average loss at step 14000: 3.151741
# Average loss at step 16000: 3.177369
# Average loss at step 18000: 3.126613
# Average loss at step 20000: 2.989715
# Nearest to had: has, have, was, were, having, sternberg, zeitung, matthews,
# Nearest to for: bdp, bysshe, recessive, ngel, against, andree, tinged, xanadu,
# Nearest to would: could, can, will, may, should, must, might, did,
# Nearest to two: three, six, five, seven, four, eight, zero, one,
# Nearest to new: marconi, floor, irrelevant, patriarchal, manganese, discovering, orie, official,
# Nearest to a: the, grapheme, any, another, gaia, rca, ceawlin, elca,
# Nearest to at: on, ucl, against, skillfully, lepidus, in, after, counseling,
# Nearest to d: b, raid, erectile, afi, amylase, momentous, harpsichordist, levelling,
# Nearest to of: in, bonfires, publicacion, seventy, with, about, cycorp, from,
# Nearest to people: authorities, migrate, elliott, undetermined, countries, others, perfecting, peoples,
# Nearest to th: hosni, restraint, perpetuated, st, ff, kampuchea, uomo, supervising,
# Nearest to only: hamdi, within, singapore, under, not, minyan, rhythmically, primarily,
# Nearest to into: through, from, conway, pillaged, cellar, exaggerating, carmack, albigensians,
# Nearest to more: less, most, increasingly, very, dreidel, greater, so, diagonals,
# Nearest to been: become, be, was, raisin, already, earthworks, being, asymptotes,
# Nearest to by: incarcerated, identifiers, ksr, from, when, conveyor, schuschnigg, cameo,
# Average loss at step 22000: 3.075482
# Average loss at step 24000: 3.038040
# Average loss at step 26000: 2.999909
# Average loss at step 28000: 3.023353
# Average loss at step 30000: 3.004296
# Nearest to had: has, have, was, having, were, yet, tradeoff, liz,
# Nearest to for: bysshe, against, disparate, andree, biruni, including, without, bdp,
# Nearest to would: could, can, will, may, should, might, must, shall,
# Nearest to two: three, four, five, six, seven, nine, eight, one,
# Nearest to new: different, patriarchal, monotonicity, floor, overcomes, affine, official, manganese,
# Nearest to a: the, gaia, any, another, brochure, aquinas, vince, redmond,
# Nearest to at: in, after, lindow, braudel, on, during, against, detergents,
# Nearest to d: b, raid, don, collegium, r, erectile, levelling, p,
# Nearest to of: in, following, criticizes, snapping, publicacion, russo, hodgson, busting,
# Nearest to people: authorities, men, others, migrate, countries, cases, children, members,
# Nearest to th: ff, uomo, st, kampuchea, matches, supervising, hosni, db,
# Nearest to only: ck, baka, conquered, pld, necessarily, branded, alpina, orgy,
# Nearest to into: through, from, around, clung, conway, exaggerating, cellar, in,
# Nearest to more: less, most, increasingly, very, larger, better, extremely, greater,
# Nearest to been: become, be, was, already, were, raisin, axum, suffered,
# Nearest to by: through, with, under, rematch, andromache, ksr, conveyor, neko,
# Average loss at step 32000: 2.827341
# Average loss at step 34000: 2.956872
# Average loss at step 36000: 2.942558
# Average loss at step 38000: 2.941325
# Average loss at step 40000: 2.930869
# Nearest to had: has, have, having, was, were, never, tradeoff, sternberg,
# Nearest to for: including, ngel, bysshe, biruni, after, akhenaten, idiot, gls,
# Nearest to would: could, will, can, may, should, might, must, cannot,
# Nearest to two: three, six, five, four, eight, seven, one, nine,
# Nearest to new: patriarchal, goldstein, retract, manganese, different, equestrian, orie, monotonicity,
# Nearest to a: another, embittered, gaia, the, discard, vince, milgram, goya,
# Nearest to at: lindow, after, experiential, ucl, randori, duvalier, multiplexing, edda,
# Nearest to d: b, levelling, raid, col, gunner, collegium, amylase, durrell,
# Nearest to of: ethicists, publicacion, glorantha, including, basra, penitence, bonfires, although,
# Nearest to people: men, children, peoples, countries, members, animals, authorities, words,
# Nearest to th: kampuchea, ff, uomo, st, supervising, hosni, jurist, queueing,
# Nearest to only: always, alpina, teg, flips, conquered, pld, necessarily, movers,
# Nearest to into: through, from, cellar, towards, on, conway, clung, around,
# Nearest to more: less, most, very, increasingly, extremely, better, larger, greater,
# Nearest to been: become, be, was, already, were, freer, recently, previously,
# Nearest to by: from, through, karenga, when, andromache, showgirl, gimme, estas,
# Average loss at step 42000: 2.954068
# Average loss at step 44000: 2.960464
# Average loss at step 46000: 2.902123
# Average loss at step 48000: 2.871255
# Average loss at step 50000: 2.842031
# Nearest to had: has, have, having, were, was, since, never, would,
# Nearest to for: while, including, against, elmendorf, during, pederasty, bdp, andree,
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Nearest to two: three, six, four, five, seven, nine, eight, one,
# Nearest to new: patriarchal, goldstein, different, comfortably, overcomes, ferromagnetic, retract, modern,
# Nearest to a: the, any, another, vince, sonnet, gaia, redmond, milgram,
# Nearest to at: in, during, duvalier, lindow, lepidus, under, herein, within,
# Nearest to d: b, concordance, johnnie, watkins, rushdie, wen, erectile, fath,
# Nearest to of: including, in, glorantha, hidalgo, although, publicacion, kn, during,
# Nearest to people: children, men, peoples, mathematicians, those, members, players, others,
# Nearest to th: st, ff, kampuchea, uomo, sabina, fifth, supervising, queueing,
# Nearest to only: necessarily, always, still, not, hamdi, even, conquered, you,
# Nearest to into: through, from, within, onto, cellar, clung, around, towards,
# Nearest to more: less, most, very, better, larger, greater, extremely, increasingly,
# Nearest to been: become, be, already, begun, recently, previously, was, entendre,
# Nearest to by: when, through, rematch, sourcebook, knox, without, mcclelland, conveyor,
# Average loss at step 52000: 2.887599
# Average loss at step 54000: 2.860637
# Average loss at step 56000: 2.859341
# Average loss at step 58000: 2.754359
# Average loss at step 60000: 2.827412
# Nearest to had: has, have, was, having, were, never, since, failed,
# Nearest to for: without, against, disparate, andree, ascending, bysshe, hermitian, when,
# Nearest to would: could, will, can, should, must, might, may, cannot,
# Nearest to two: three, four, six, seven, five, one, eight, nine,
# Nearest to new: different, patriarchal, voor, floor, goldstein, autodesk, silt, manganese,
# Nearest to a: another, vince, gaia, any, embittered, the, ceawlin, goya,
# Nearest to at: during, in, lindow, inexperience, on, herein, under, skillfully,
# Nearest to d: b, r, h, l, col, concordance, n, erectile,
# Nearest to of: although, publicacion, including, puranas, basra, glorantha, cooley, amusingly,
# Nearest to people: children, men, peoples, scientists, mathematicians, others, players, individuals,
# Nearest to th: fifth, kampuchea, uomo, st, jurist, sabina, ff, third,
# Nearest to only: easily, universally, always, generally, num, necessarily, alpina, hamdi,
# Nearest to into: through, onto, within, from, clung, towards, along, during,
# Nearest to more: less, most, very, greater, larger, quite, increasingly, extremely,
# Nearest to been: become, be, already, were, begun, was, recently, unambiguous,
# Nearest to by: mcclelland, from, knox, illustrating, with, pemberton, under, appel,
# Average loss at step 62000: 2.833141
# Average loss at step 64000: 2.773396
# Average loss at step 66000: 2.764704
# Average loss at step 68000: 2.713079
# Average loss at step 70000: 2.786185
# Nearest to had: has, have, having, was, were, never, according, failed,
# Nearest to for: bdp, against, without, idiot, elmendorf, disparate, andree, speculators,
# Nearest to would: could, will, might, should, must, can, may, cannot,
# Nearest to two: four, three, six, seven, five, eight, one, nine,
# Nearest to new: patriarchal, different, modern, monotonicity, floor, manganese, moscow, goldstein,
# Nearest to a: another, the, any, ceawlin, gaia, forfeited, sonnet, goya,
# Nearest to at: near, lindow, on, in, toward, around, under, within,
# Nearest to d: b, rushdie, lamb, johnnie, concordance, amylase, erectile, wen,
# Nearest to of: in, amusingly, witherspoon, spaghetti, publicacion, cooley, hidalgo, severn,
# Nearest to people: children, men, peoples, women, mathematicians, individuals, players, countries,
# Nearest to th: fifth, third, sabina, seventh, kampuchea, st, fished, suk,
# Nearest to only: even, conquered, sparky, hamdi, neoconservatism, always, necessarily, stoned,
# Nearest to into: through, within, onto, under, from, clung, hyi, across,
# Nearest to more: less, most, greater, very, better, quite, increasingly, larger,
# Nearest to been: become, be, already, was, begun, recently, were, previously,
# Nearest to by: conveyor, through, knox, illustrating, when, with, sourcebook, ammanati,
# Average loss at step 72000: 2.798939
# Average loss at step 74000: 2.639672
# Average loss at step 76000: 2.806560
# Average loss at step 78000: 2.823290
# Average loss at step 80000: 2.783457
# Nearest to had: has, have, was, having, were, never, failed, eventually,
# Nearest to for: after, without, during, including, idiot, when, while, against,
# Nearest to would: could, will, might, should, can, must, may, cannot,
# Nearest to two: three, four, six, five, eight, seven, one, nine,
# Nearest to new: patriarchal, different, moscow, modern, floor, falco, unique, multi,
# Nearest to a: another, any, every, no, the, embittered, vince, memos,
# Nearest to at: in, under, during, herein, skillfully, toward, around, near,
# Nearest to d: b, collegium, dominating, johnnie, levelling, watkins, concordance, c,
# Nearest to of: publicacion, including, halide, bonfires, and, tala, in, safin,
# Nearest to people: children, men, mathematicians, peoples, individuals, jews, persons, women,
# Nearest to th: fifth, sabina, eight, five, jurist, st, six, sacu,
# Nearest to only: theoretically, necessarily, num, teri, even, generally, neoconservatism, either,
# Nearest to into: through, onto, within, across, from, along, around, tranquility,
# Nearest to more: less, very, most, greater, rather, better, increasingly, quite,
# Nearest to been: become, be, was, already, were, begun, recently, unambiguous,
# Nearest to by: when, during, using, through, illustrating, with, without, conveyor,
# Average loss at step 82000: 2.667649
# Average loss at step 84000: 2.768359
# Average loss at step 86000: 2.739894
# Average loss at step 88000: 2.753706
# Average loss at step 90000: 2.733668
# Nearest to had: has, have, having, was, were, since, is, licenced,
# Nearest to for: filing, cycorp, idiot, cur, bysshe, bdp, when, after,
# Nearest to would: could, should, will, might, can, must, may, cannot,
# Nearest to two: four, three, six, eight, five, seven, one, zero,
# Nearest to new: modern, patriarchal, bicameral, old, josaphat, falco, london, monstrous,
# Nearest to a: another, enough, ceawlin, forfeited, the, any, honeybee, elca,
# Nearest to at: near, in, during, under, lindow, toward, after, damme,
# Nearest to d: b, l, c, concordance, r, leftrightarrow, dominating, col,
# Nearest to of: publicacion, including, edgerton, fibrous, linton, katrina, inquisitor, despite,
# Nearest to people: children, men, mathematicians, women, peoples, persons, individuals, players,
# Nearest to th: fifth, third, sabina, eight, st, fourth, kampuchea, seventh,
# Nearest to only: until, either, necessarily, always, num, flips, flushed, universally,
# Nearest to into: through, onto, within, from, across, hyi, off, cellar,
# Nearest to more: less, most, greater, increasingly, very, highly, quite, rather,
# Nearest to been: become, be, begun, recently, were, already, remained, was,
# Nearest to by: through, when, illustrating, using, mcclelland, conveyor, pemberton, knox,
# Average loss at step 92000: 2.683813
# Average loss at step 94000: 2.723425
# Average loss at step 96000: 2.707096
# Average loss at step 98000: 2.367869
# Average loss at step 100000: 2.391801
# Nearest to had: has, have, having, was, were, never, is, did,
# Nearest to for: idiot, after, austronesian, gls, drifting, bdp, against, disparate,
# Nearest to would: could, will, might, should, can, must, may, cannot,
# Nearest to two: three, four, five, six, eight, seven, nine, zero,
# Nearest to new: patriarchal, moscow, monotonicity, kets, bicameral, modern, former, london,
# Nearest to a: embittered, vince, another, manco, ceawlin, forfeited, mrs, the,
# Nearest to at: in, near, during, around, after, on, skillfully, herein,
# Nearest to d: b, crankshafts, wen, dominating, concordance, harpsichordist, accountants, watkins,
# Nearest to of: in, despite, edgerton, publicacion, gizzard, includes, inquisitor, rhenish,
# Nearest to people: children, men, women, mathematicians, persons, individuals, person, peoples,
# Nearest to th: fifth, seventh, st, sabina, fourth, rush, third, kampuchea,
# Nearest to only: num, first, necessarily, last, flushed, autism, theoretically, neoconservatism,
# Nearest to into: through, onto, within, across, under, down, festivities, darling,
# Nearest to more: less, most, greater, very, rather, increasingly, faster, larger,
# Nearest to been: become, be, already, begun, recently, were, remained, was,
# Nearest to by: through, including, pimlico, from, using, andromache, when, illustrating,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
